# %%
import pandas as pd

data = {
    'Name': ['A', 'B', 'C', 'D'],
    'Gender': ['M', 'F', 'F', 'M']
}

df = pd.DataFrame(data)
df
# Out:
#   Name Gender
# 0    A      M
# 1    B      F
# 2    C      F
# 3    D      M

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Pandas Series
name_series = df['Name']
print(type(name_series))

gender_series = df['Gender']
print(type(gender_series))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
new_df = pd.concat(
    [name_series, gender_series],
    axis = 1
)

print(type(new_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # **Problem A**
#
# Give Pokemon.csv : https://drive.google.com/file/d/11fjFxxa2RfoLCJUQ_OSTm3GfMZHVy8Gy/view

# %%
# !gdown --id 11fjFxxa2RfoLCJUQ_OSTm3GfMZHVy8Gy
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=11fjFxxa2RfoLCJUQ_OSTm3GfMZHVy8Gy
# To: /content/Pokemon.csv
# 100% 44.0k/44.0k [00:00<00:00, 21.2MB/s]

# %%
# Read CSV
import pandas as pd
import numpy as np

DATASET_PATH = '/content/Pokemon.csv'
data = pd.read_csv(DATASET_PATH)

# %%
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Save CSV
data.to_csv('modified.csv') # To csv format

data.to_excel('modified.xlsx', index = False) # To xlsx format, remove index col.

data.to_csv('modified.txt', sep = '\t') # To CSV format with columns seperated by 'tab'

# %%
# Get infor statistic
data.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
# Head method
data.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Tail method
data.tail(8)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 792      131       98     99           6       True
# 793      131       98     99           6       True
# 794       81       95     95           6       True
# 795      100      150     50           6       True
# ...

# %%
# Get headers
print(data.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Get specific columns
print(data[['Name']].head())
print('\n')
print(data[['Name', 'Total', 'Attack']][:10:2])
# Out:
#                     Name
# 0              Bulbasaur
# 1                Ivysaur
# 2               Venusaur
# 3  VenusaurMega Venusaur
# 4             Charmander
#
#
#                         Name  Total  Attack
# 0                  Bulbasaur    318      49
# 2                   Venusaur    525      82
# 4                 Charmander    309      52
# 6                  Charizard    534      84
# 8  CharizardMega Charizard Y    634     104

# %%
# Remove colums
data.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
data = data.drop(columns=['Total'])
data.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
# Create Column
data['Total'] = data['Attack'] + data['Defense'] + data['HP']
data.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    143
# 1           1      False    185
# 2           1      False    245

# %%
# Arranging order
cols = list(data.columns.values)
print(cols)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total']

# %%
# Cách 1
data[['Name', 'Total', 'Attack', 'Speed']].head()
# Out:
#                     Name  Total  Attack  Speed
# 0              Bulbasaur    143      49     45
# 1                Ivysaur    185      62     60
# 2               Venusaur    245      82     80
# 3  VenusaurMega Venusaur    303     100     80
# 4             Charmander    134      52     65

# %%
# Cách 2
cols[0:4]
# Out:
# ['#', 'Name', 'Type 1', 'Type 2']

# %%
data[cols[0:4]]
# Out:
#        #                   Name   Type 1  Type 2
# 0      1              Bulbasaur    Grass  Poison
# 1      2                Ivysaur    Grass  Poison
# 2      3               Venusaur    Grass  Poison
# 3      3  VenusaurMega Venusaur    Grass  Poison
# 4      4             Charmander     Fire     NaN
# ..   ...                    ...      ...     ...
# 795  719                Diancie     Rock   Fairy
# 796  719    DiancieMega Diancie     Rock   Fairy
# 797  720    HoopaHoopa Confined  Psychic   Ghost
# 798  720     HoopaHoopa Unbound  Psychic    Dark
# 799  721              Volcanion     Fire   Water
#
# [800 rows x 4 columns]

# %%
data[cols[0:4] + [cols[-1]] + cols[4:-1]].head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    143  45      49       49
# 1  2                Ivysaur  Grass  Poison    185  60      62       63
# 2  3               Venusaur  Grass  Poison    245  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    303  80     100      123
# 4  4             Charmander   Fire     NaN    134  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## **Selecting rows**

# %%
# By index
data.iloc[[3]]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 3      120     80           1      False    303

# %%
data.iloc[[3, 6]]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 3      120     80           1      False    303
# 6       85    100           1      False    240

# %%
data.iloc[2:10:2]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 2      100     80           1      False    245
# 4       50     65           1      False    134
# 6       85    100           1      False    240
# 8      115    100           1      False    260

# %%
# By condition
data.loc[data['Legendary'] == True].head(2)
# Out:
#        #      Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 156  144  Articuno       Ice  Flying  90      85      100       95      125
# 157  145    Zapdos  Electric  Flying  90      90       85      125       90
#
#      Speed  Generation  Legendary  Total
# 156     85           1       True    275
# 157    100           1       True    265

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    143
# 1       80     60           1      False    185
# 2      100     80           1      False    245
# 3      120     80           1      False    303
# 4       50     65           1      False    134

# %%
data.iloc[3,4]
# Out:
# np.int64(80)

# %%
data.loc[data['Attack'] == 49, ['Name']]
# Out:
#           Name
# 0    Bulbasaur
# 166  Chikorita
# 506    Finneon

# %% [markdown]
# ## **Filtering**

# %%
# By .loc
data.loc[(data['Type 1'] == 'Grass') & (data['Type 2'] == 'Poison')].head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    143
# 1           1      False    185
# 2           1      False    245

# %%
data.loc[(data['Type 1'] == 'Grass') | (data['Type 2'] == 'Poison')][0::10].loc[data['HP'] > 50].head(3)
# Out:
#        #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 50    45  Vileplume  Grass  Poison  75      80       85      110       90
# 101   94     Gengar  Ghost  Poison  60      65       60      130       75
# 197  182  Bellossom  Grass     NaN  75      80       95       90      100
#
#      Speed  Generation  Legendary  Total
# 50      50           1      False    240
# 101    110           1      False    185
# 197     50           2      False    250

# %%
# By Regex
import re
data.loc[data['Name'].str.contains('Mega')].head(3) # Chỉ lọc được một giá trị
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 3      120     80           1      False    303
# 7       85    100           1      False    319
# 8      115    100           1      False    260

# %%
data.loc[data['Type 1'].str.contains('Fire|Grass', regex=True)].head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    143
# 1           1      False    185
# 2           1      False    245

# %%
data.loc[data['Name'].str.contains('pi[a-z]*', flags=re.I, regex=True)].head(3) # flags=re.I không phân biệt hoa thường
# Out:
#      #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 13  10   Caterpie     Bug     NaN  45      30       35       20       20
# 20  16     Pidgey  Normal  Flying  40      45       40       35       35
# 21  17  Pidgeotto  Normal  Flying  63      60       55       50       50
#
#     Speed  Generation  Legendary  Total
# 13     45           1      False    110
# 20     56           1      False    125
# 21     71           1      False    178

# %%
data.loc[data['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)].head(3)
# Out:
#      #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  16     Pidgey  Normal  Flying  40      45       40       35       35
# 21  17  Pidgeotto  Normal  Flying  63      60       55       50       50
# 22  18    Pidgeot  Normal  Flying  83      80       75       70       70
#
#     Speed  Generation  Legendary  Total
# 20     56           1      False    125
# 21     71           1      False    178
# 22    101           1      False    238

# %%
data.loc[data['Name'].str.contains('^pi.*', flags=re.I, regex=True)].head(3)
# Out:
#      #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  16     Pidgey  Normal  Flying  40      45       40       35       35
# 21  17  Pidgeotto  Normal  Flying  63      60       55       50       50
# 22  18    Pidgeot  Normal  Flying  83      80       75       70       70
#
#     Speed  Generation  Legendary  Total
# 20     56           1      False    125
# 21     71           1      False    178
# 22    101           1      False    238

# %% [markdown]
# ## **Sorting**

# %%
data.sort_values('Type 1').head(3)
# Out:
#        #      Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 600  540  Sewaddle    Bug  Grass  45      53       70       40       60
# 136  127    Pinsir    Bug    NaN  65     125      100       55       70
# 457  412     Burmy    Bug    NaN  40      29       45       29       45
#
#      Speed  Generation  Legendary  Total
# 600     42           5      False    168
# 136     85           1      False    290
# 457     36           4      False    114

# %%
data.sort_values('Type 1', ascending=False).head(3)
# Out:
#        #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 371  339  Barboach  Water  Ground  50      48       43       46       41
# 97    90  Shellder  Water     NaN  30      65      100       45       25
# 240  222   Corsola  Water    Rock  55      55       85       65       85
#
#      Speed  Generation  Legendary  Total
# 371     60           3      False    141
# 97      40           1      False    195
# 240     35           2      False    195

# %%
data.sort_values(['Type 1', 'HP'], ascending=[1, 0]).head(3)
# Out:
#        #       Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 520  469    Yanmega    Bug    Flying  86      76       86      116       56
# 698  637  Volcarona    Bug      Fire  85      60       65      135      105
# 231  214  Heracross    Bug  Fighting  80     125       75       40       95
#
#      Speed  Generation  Legendary  Total
# 520     95           4      False    248
# 698    100           5      False    210
# 231     85           2      False    280

# %% [markdown]
# ## **Reset Index**

# %%
new_data = data.loc[(data['Type 1'] == 'Grass') | (data['Type 2'] == 'Poison')][0::10].loc[data['HP'] > 50].head(3)
new_data
# Out:
#        #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 50    45  Vileplume  Grass  Poison  75      80       85      110       90
# 101   94     Gengar  Ghost  Poison  60      65       60      130       75
# 197  182  Bellossom  Grass     NaN  75      80       95       90      100
#
#      Speed  Generation  Legendary  Total
# 50      50           1      False    240
# 101    110           1      False    185
# 197     50           2      False    250

# %%
new_data = new_data.reset_index()
new_data
# Out:
#    index    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0     50   45  Vileplume  Grass  Poison  75      80       85      110
# 1    101   94     Gengar  Ghost  Poison  60      65       60      130
# 2    197  182  Bellossom  Grass     NaN  75      80       95       90
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       90     50           1      False    240
# 1       75    110           1      False    185
# 2      100     50           2      False    250

# %%
new_data = new_data.reset_index(drop = True) # Xóa cột index cũ
new_data
# Out:
#    index    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0     50   45  Vileplume  Grass  Poison  75      80       85      110
# 1    101   94     Gengar  Ghost  Poison  60      65       60      130
# 2    197  182  Bellossom  Grass     NaN  75      80       95       90
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       90     50           1      False    240
# 1       75    110           1      False    185
# 2      100     50           2      False    250

# %%
new_data.reset_index(drop = True, inplace = True) # Không cần phải gán thành new_data mà nó vẫn thay đổi new_data
new_data
# Out:
#    index    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0     50   45  Vileplume  Grass  Poison  75      80       85      110
# 1    101   94     Gengar  Ghost  Poison  60      65       60      130
# 2    197  182  Bellossom  Grass     NaN  75      80       95       90
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       90     50           1      False    240
# 1       75    110           1      False    185
# 2      100     50           2      False    250

# %% [markdown]
# ## **Groupby**

# %%
data.groupby(['Type 1']).mean(numeric_only=True).sort_values('Defense', ascending = False).head(10)
# Out:
#                  #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel   442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock    392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon  474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground  356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost   486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water   303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice     423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass   344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug     334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark    461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
#
#             Speed  Generation  Legendary       Total
# Type 1
# Steel   55.259259    3.851852   0.148148  284.296296
# ...

# %%
data.groupby(['Type 1', 'Type 2']).count()
# Out:
#                   #  Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Bug    Electric   2     2   2       2        2        2        2      2
#        Fighting   2     2   2       2        2        2        2      2
#        Fire       2     2   2       2        2        2        2      2
#        Flying    14    14  14      14       14       14       14     14
#        Ghost      1     1   1       1        1        1        1      1
# ...              ..   ...  ..     ...      ...      ...      ...    ...
# Water  Ice        3     3   3       3        3        3        3      3
#        Poison     3     3   3       3        3        3        3      3
#        Psychic    5     5   5       5        5        5        5      5
#        Rock       4     4   4       4        4        4        4      4
#        Steel      1     1   1       1        1        1        1      1
#
#                  Generation  Legendary  Total
# Type 1 Type 2
# ...

# %%
df = data.groupby(['Type 1'])[['Attack', 'Defense']].apply(lambda x : np.sum(x) / len(x))
df.head(3)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
#             Attack    Defense
# Type 1
# Bug      70.971014  70.724638
# Dark     88.387097  70.225806
# Dragon  112.125000  86.375000

# %%
df = data.groupby(['Type 1']).agg({
    'Attack': 'mean',
    'Defense': 'sum',
    'Speed': lambda x: len(x)
})
df.head(3)
# Out:
#             Attack  Defense  Speed
# Type 1
# Bug      70.971014     4880     69
# Dark     88.387097     2177     31
# Dragon  112.125000     2764     32

# %%
df = data.groupby('Type 1')[['Attack', 'Defense']].agg(['mean', 'max', 'min'])
df.head(3)
# Out:
#             Attack             Defense
#               mean  max min       mean  max min
# Type 1
# Bug      70.971014  185  10  70.724638  230  30
# Dark     88.387097  150  50  70.225806  125  30
# Dragon  112.125000  180  50  86.375000  130  35

# %%
df = data.groupby('Type 1').agg({
    'Attack':['mean', 'max', 'min'],
    'Defense': ['mean', 'max']
})
df.head(3)
# Out:
#             Attack             Defense
#               mean  max min       mean  max
# Type 1
# Bug      70.971014  185  10  70.724638  230
# Dark     88.387097  150  50  70.225806  125
# Dragon  112.125000  180  50  86.375000  130

# %%
df = data.groupby('Type 1').agg(
    mean_attack=('Attack', 'mean'),
    max_attack=('Attack', 'max'),
    mean_defense=('Defense', 'mean'),
    max_defense=('Defense', 'max')
)
df.head(3)
# Out:
#         mean_attack  max_attack  mean_defense  max_defense
# Type 1
# Bug       70.971014         185     70.724638          230
# Dark      88.387097         150     70.225806          125
# Dragon   112.125000         180     86.375000          130

# %% [markdown]
# # **Problem B**
#
# Time-series data: là kiểu dữ liệu có yếu tố thời gian.
#
# Description: **Give Daily minimum temperature dataset**
# Dataset B: https://drive.google.com/file/d/1fS6pGYj5FMZa8AsBHJ85jaiBJqWA4dqg/view?usp=sharing

# %%
# !gdown --id 1fS6pGYj5FMZa8AsBHJ85jaiBJqWA4dqg
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1fS6pGYj5FMZa8AsBHJ85jaiBJqWA4dqg
# To: /content/timeseries_daily-minimum-temperatures.csv
# 100% 55.9k/55.9k [00:00<00:00, 59.6MB/s]

# %%
DATASET_PATH = './timeseries_daily-minimum-temperatures.csv'

# Read data from .csv file
ts_df = pd.read_csv(DATASET_PATH)

print(ts_df.shape)
print(ts_df.dtypes)
ts_df.head(3)
# Out:
# (3650, 2)
# Date                          object
# Daily minimum temperatures    object
# dtype: object
#        Date Daily minimum temperatures
# 0  1/1/1981                       20.7
# 1  1/2/1981                       17.9
# 2  1/3/1981                       18.8

# %%
# Date is also a unique value:
ts_df['Date'] = pd.to_datetime(ts_df['Date']) # Lúc đầu pandas hiểu đó là string nên Ép kiểu thành date_time
print(ts_df.dtypes)
# Change index
ts_df = ts_df.set_index('Date')
ts_df.head(3)
# Out:
# Date                          datetime64[ns]
# Daily minimum temperatures            object
# dtype: object
#            Daily minimum temperatures
# Date
# 1981-01-01                       20.7
# 1981-01-02                       17.9
# 1981-01-03                       18.8

# %% [markdown]
# ## **Add weekday, month, year**

# %%
ts_df = pd.read_csv(DATASET_PATH, index_col = 0, parse_dates = True)

ts_df['Year'] = ts_df.index.year
ts_df['Month'] = ts_df.index.month
ts_df['Day'] = ts_df.index.day
ts_df['Weekday Day'] = ts_df.index.day_name()

ts_df.sample(5, random_state = 0)
# Out:
#            Daily minimum temperatures  Year  Month  Day Weekday Day
# Date
# 1990-08-20                        9.7  1990      8   20      Monday
# 1982-07-24                        6.6  1982      7   24    Saturday
# 1983-09-19                         12  1983      9   19      Monday
# 1986-09-28                        6.9  1986      9   28      Sunday
# 1988-01-12                       18.3  1988      1   12     Tuesday

# %%
ts_df.dtypes
# Out:
# Daily minimum temperatures    object
# Year                           int32
# Month                          int32
# Day                            int32
# Weekday Day                   object
# dtype: object

# %%
# Convert object of 'Daily minimum temperatures' into float64
ts_df['Daily minimum temperatures'] = pd.to_numeric(ts_df['Daily minimum temperatures'], errors = 'coerce')
ts_df.dtypes
# Out:
# Daily minimum temperatures    float64
# Year                            int32
# Month                           int32
# Day                             int32
# Weekday Day                    object
# dtype: object

# %% [markdown]
# ## **Time-based indexing**
# Filter rows by dd/mm/yy

# %%
ts_df.loc['1990-01-01':'1991-01-01']
# Out:
#             Daily minimum temperatures  Year  Month  Day Weekday Day
# Date
# 1990-01-01                        14.8  1990      1    1      Monday
# 1990-01-02                        13.3  1990      1    2     Tuesday
# 1990-01-03                        15.6  1990      1    3   Wednesday
# 1990-01-04                        14.5  1990      1    4    Thursday
# 1990-01-05                        14.3  1990      1    5      Friday
# ...                                ...   ...    ...  ...         ...
# 1990-12-27                        14.0  1990     12   27    Thursday
# 1990-12-28                        13.6  1990     12   28      Friday
# 1990-12-29                        13.5  1990     12   29    Saturday
# 1990-12-30                        15.7  1990     12   30      Sunday
# 1990-12-31                        13.0  1990     12   31      Monday
#
# [365 rows x 5 columns]

# %%
ts_df.loc['1990-01']
# Out:
#             Daily minimum temperatures  Year  Month  Day Weekday Day
# Date
# 1990-01-01                        14.8  1990      1    1      Monday
# 1990-01-02                        13.3  1990      1    2     Tuesday
# 1990-01-03                        15.6  1990      1    3   Wednesday
# 1990-01-04                        14.5  1990      1    4    Thursday
# 1990-01-05                        14.3  1990      1    5      Friday
# 1990-01-06                        15.3  1990      1    6    Saturday
# 1990-01-07                        16.4  1990      1    7      Sunday
# 1990-01-08                        14.8  1990      1    8      Monday
# 1990-01-09                        17.4  1990      1    9     Tuesday
# 1990-01-10                        18.8  1990      1   10   Wednesday
# 1990-01-11                        22.1  1990      1   11    Thursday
# 1990-01-12                        19.0  1990      1   12      Friday
# ...

# %% [markdown]
# ## **Visualize time-series data**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(9, 4)})
col_to_plot = 'Daily minimum temperatures'
ts_df[col_to_plot].plot(linewidth=0.8)
plt.ylabel(col_to_plot)
plt.show()

# %%
cols_plot = ['Daily minimum temperatures']
ts_df[cols_plot].plot(
    marker = '.',
    alpha = 0.5,
    linestyle = 'None',
    figsize = (10, 4),
    subplots = True
)
plt.ylabel(col_to_plot)
plt.show()

# %% [markdown]
# ## **Seasonality visualization**
# **Seasonality** is a characteristic of a time series in which the data experiences regular and predictable changes recur every calendar year.

# %%
ts_df['Year'] = ts_df.index.year
ts_df['Month'] = ts_df.index.month
ts_df['Day'] = ts_df.index.day
ts_df['Weekday Day'] = ts_df.index.day_name()

# %%
COL_NAME = 'Daily minimum temperatures'
plt.figure(figsize=(10, 4))
sns.boxplot(data=ts_df, x = 'Month', y = COL_NAME)
plt.ylabel('Temperature')
plt.title(COL_NAME)
plt.show()

# %% [markdown]
# ## **Frequencies**

# %%
pd.date_range('1998-03-10', '1998-03-15', freq='D') # Day  frequency
# Out:
# DatetimeIndex(['1998-03-10', '1998-03-11', '1998-03-12', '1998-03-13',
#                '1998-03-14', '1998-03-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2004-09-20', periods=8, freq='H')
# Out:
# /tmp/ipykernel_15674/2091515546.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range('2004-09-20', periods=8, freq='H')
# DatetimeIndex(['2004-09-20 00:00:00', '2004-09-20 01:00:00',
#                '2004-09-20 02:00:00', '2004-09-20 03:00:00',
#                '2004-09-20 04:00:00', '2004-09-20 05:00:00',
#                '2004-09-20 06:00:00', '2004-09-20 07:00:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
# To select an arbitrary seqence of date/time values from a pandas time series,
# we need to use a DatetimeIndex, rather than simply a list of date/time strings
times_sample = pd.to_datetime(['1981-01-01', '1981-01-04', '1981-01-08'])
# Select the specified dates and just the consumption colum
consum_sample = ts_df.loc[times_sample, ['Daily minimum temperatures']].copy()
consum_sample
# Out:
#             Daily minimum temperatures
# 1981-01-01                        20.7
# 1981-01-04                        14.6
# 1981-01-08                        17.4

# %%
# Convert the data to daily frequency, without filling any missings
consum_freq = consum_sample.asfreq('D')
# Create a colums with missing forward filled
consum_freq['Daily minimum temperatures - Forward Fill'] = consum_sample.asfreq('D', method='ffill')
consum_freq
# Out:
#             Daily minimum temperatures  \
# 1981-01-01                        20.7
# 1981-01-02                         NaN
# 1981-01-03                         NaN
# 1981-01-04                        14.6
# 1981-01-05                         NaN
# 1981-01-06                         NaN
# 1981-01-07                         NaN
# 1981-01-08                        17.4
#
#             Daily minimum temperatures - Forward Fill
# 1981-01-01                                       20.7
# 1981-01-02                                       20.7
# 1981-01-03                                       20.7
# 1981-01-04                                       14.6
# 1981-01-05                                       14.6
# 1981-01-06                                       14.6
# 1981-01-07                                       14.6
# 1981-01-08                                       17.4

# %% [markdown]
# ## **Resampling**
#
# Thay đổi frequency của data

# %%
data_columns = ['Daily minimum temperatures']
ts_weekly_mean = ts_df[data_columns].resample('W').mean()
ts_weekly_mean.head(3)
# Out:
#             Daily minimum temperatures
# Date
# 1981-01-04                   18.000000
# 1981-01-11                   17.542857
# 1981-01-18                   20.371429

# %%
print(ts_df.shape)
print(ts_weekly_mean.shape[0])
# Out:
# (3650, 5)
# 523

# %%
# Start and end of the date range to extract
start, end = '1981-01', '1981-12'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots()
ax.plot(ts_df.loc[start:end, 'Daily minimum temperatures'],
         marker='.', linestyle='-', linewidth=0.5, label='Daily')
ax.plot(ts_weekly_mean.loc[start:end, 'Daily minimum temperatures'],
         marker='o', linestyle='-', label='Weekly Mean Resample')
ax.set_ylabel('Temperature')
ax.legend()
plt.show()

# %%
# Compute the annual sums, setting the value to NaN for any year which has
# fewer than 360 days of data
ts_annual_df = ts_df[data_columns].resample('A').sum(min_count=360)
# The default index of the resampled DataFrame is the last day of each year
# to the year component
ts_annual_df = ts_annual_df.set_index(ts_annual_df.index.year)
ts_annual_df.index.name = 'Year'
# Compte the ratio of Wind+Solar to Consumption
ts_annual_df.tail(3)
# Out:
# /tmp/ipykernel_15674/3774488756.py:3: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   ts_annual_df = ts_df[data_columns].resample('A').sum(min_count=360)
#       Daily minimum temperatures
# Year
# 1988                      4369.8
# 1989                      4110.6
# 1990                      4259.4

# %%
# Plot from 1981 onwards, because there is no solar prodction data in earlier years
ax = ts_annual_df.loc[1981:, 'Daily minimum temperatures'].plot.bar(color='C0')
ax.set_ylabel('Fraction')
ax.set_title('Anuall Temperature')
ax.set_title('Annual Temperature')
plt.xticks(rotation = 0)
plt.show()
